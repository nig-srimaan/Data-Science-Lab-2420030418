# %% [markdown]
# <a href="https://colab.research.google.com/github/Karishma-2007/Data-Science-Lab/blob/main/week_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd

iris=load_iris()

df=pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

sns.histplot(df['sepal length (cm)'],kde=True)

plt.show()

# %%
sns.boxplot(x=df['sepal length (cm)'])
plt.show()

# %%
sns.scatterplot(
    x=df['sepal length (cm)'],
    y=df['sepal width (cm)']
)

plt.show()

# %%
sns.heatmap(df.corr(),annot=True)

plt.show()

# %%
sns.pairplot(df)

plt.show()
